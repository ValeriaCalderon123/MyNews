# %%
from apps.source.models import Source
import requests
import bs4
import re

# %%
sources = Source.objects.filter(calification__gte=100)

# %%
s1 = sources.last()

# %%
s1.search_articles_link
# Out:
# 'story-item__information-box'

# %%
search_key = 'martin vizcarra'

# %%
search_url = s1.search_url + search_key

# %%
search_url
# Out:
# 'https://peru21.pe/buscar/martin vizcarra'

# %%
response = requests.get(search_url)

# %%
response.text
# Out:
# '<!DOCTYPE html><html itemscope="" itemType="http://schema.org/WebPage" lang="es"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="lang" content="es"/><meta name="resource-type" content="document"/><meta content="global" name="distribution"/><meta name="robots" content="index, follow"/><meta name="GOOGLEBOT" content="index follow"/><meta name="Author" content="Peru21"/><title>martin vizcarra en Noticias | NOTICIAS PERU21 PERÚ</title><link rel="preconnect dns-prefetch" href="//cdnc.peru21.pe"/><link rel="preconnect dns-prefetch" href="//cdna.peru21.pe"/><link rel="preconnect dns-prefetch" href="//d1r08wok4169a5.cloudfront.net"/><link rel="preconnect dns-prefetch" href="//elcomercio-elcomercio-prod.cdn.arcpublishing.com"/><link rel="preconnect dns-prefetch" href="//arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com"/><link rel="preconnect dns-prefetch" href="//s.go-mpulse.net"/><link rel="preconnect dns-prefetch" href="//fonts.gstatic.com"/><link rel="preconnect dns-prefetch" href="//ajax.googleapis.com"/><link rel="preconnect dns-prefetch" href="//fonts.googleapis.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//tags.bluekai.com"/><link rel="preconnect dns-prefetch" href="//tags.bkrtx.com"/><link rel="preconnect dns-prefetch" href="//static.chartbeat.com"/><link rel="preconnect dns-prefetch" href="//scomcluster.cxense.com"/><link rel="preconnect dns-prefetch" href="//sb.scorecardresearch.com"/><link rel="preconnect dns-prefetch" href="//ping.chartbeat.net"/><link rel="preconnect dns-prefetch" href="//mab.chartbeat.com"/><link rel="preconnect dns-prefetch" href="//cdn.cxense.com"/><link rel="preconnect dns-prefetch" href="//arc-subs-sdk.s3.amazonaws.com"/><link rel="preconnect dns-prefetch" href="//acdn.adnxs.com"/><link href="https://fonts.googleapis.com/css?family=Lato:300,400,700,900|Exo:500|Roboto:400,700,900&amp;display=swap" rel="stylesheet"/><link rel="stylesheet" href="https://cdnc.peru21.pe/dist/peru21/css/style.css?d=1155"/><link rel="shortcut icon" type="image/png" href="https://cdna.peru21.pe/resources/dist/peru21/images/favicon.png?d=1"/><link rel="apple-touch-icon" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon.png?d=1"/><link rel="apple-touch-icon" sizes="76x76" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-76x76.png?d=1"/><link rel="apple-touch-icon" sizes="120x120" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-120x120.png?d=1"/><link rel="apple-touch-icon" sizes="144x144" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-144x144.png?d=1"/><link rel="apple-touch-icon" sizes="152x152" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-152x152.png?d=1"/><link rel="apple-touch-icon" sizes="180x180" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-180x180.png?d=1"/><link rel="canonical" href="https://peru21.pe/buscar/martin%20vizcarra/"/><meta name="theme-color" content="#005fa5"/><meta name="msapplication-TileColor" content="#005fa5"/><meta name="apple-mobile-web-app-title" content="Peru21"/><meta name="application-name" content="Peru21"/><script type="application/ld+json">{"@context" : "http://schema.org", "@type" : "Organization", "name" : "Peru21", "url" : "https://peru21.pe/", "logo": "https://cdna.peru21.pe/resources/dist/peru21/images/logo-peru21.jpg?d=1",  "sameAs" : [ "https://www.facebook.com/peru21","https://twitter.com/peru21noticias" ] }</script><script type="text/javascript">\n          var _sf_async_config = _sf_async_config || {}\n          /** CONFIGURATION ST ...

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')

articles_links = soup.select('.'+s1.search_articles_link)
#articles_links[0].find('a')
articles = [article.find('a')['href'] for article in articles_links]


top_articles = []

for i in range(min(10, len(articles))):
    top_articles.append(articles[i])
top_articles
# Out:
# ['/politica/mercedes-araoz-fiscal-de-la-nacion-archivo-denuncia-jurar-como-presidenta-noticia/',
#  '/economia/union-demanda-de-pan-envasado-se-normaliza-pero-consumo-sigue-en-aumento-noticia/',
#  '/lima/jorge-munoz-a-martin-vizcarra-por-subsidio-al-metropolitano-transferencias-por-puchos-no-sirven-nndc-noticia/',
#  '/lima/coronavirus-peru-metro-clausura-de-local-de-la-pascana-de-comas-es-ilegal-y-se-impugnara-medida-estado-de-emergencia-covid-19-nndc-noticia/',
#  '/politica/martin-vizcarra-sobre-lo-aprobado-por-el-congreso-no-tengo-ningun-temor-pero-estoy-de-salida-inmunidad-parlamentaria-nndc-noticia/',
#  '/politica/congreso-de-la-republica-martin-vizcarra-juristas-piden-al-titular-del-congreso-detener-el-proceso-de-aprobacion-de-las-reformas-noticia/',
#  '/politica/presidente-vizcarra-convoca-al-consejo-de-estado-para-abordar-impase-sobre-reforma-politica-congreso-de-la-republica-noticia/',
#  '/politica/elecciones-2021-martin-vizcarra-convoco-hoy-a-elecciones-para-abril-del-proximo-ano-noticia/',
#  '/politica/martin-vizcarra-convoco-para-manana-al-consejo-de-estado-noticia/',
#  '/politica/hospital-de-ate-se-convertira-en-el-instituto-nacional-de-medicina-critica-tras-la-pandemia-anuncio-martin-vizcarra-pandemia-noticia/']

# %%
is_well_formed_url = re.compile(r'^https?://.+/.+$')
is_root_path = re.compile(r'^/.+$')

def build_link(host, link):
    if is_well_formed_url.match(link):
        return link
    elif is_root_path.match(link):
        return '{host}{uri}'.format(host=host, uri=link[1:len(link)])
    else:
        link

# %%
for i in range(len(top_articles)):
    top_articles[i] = build_link(s1.host, top_articles[i])

# %%
top_articles
# Out:
# ['https://peru21.pe/politica/mercedes-araoz-fiscal-de-la-nacion-archivo-denuncia-jurar-como-presidenta-noticia/',
#  'https://peru21.pe/economia/union-demanda-de-pan-envasado-se-normaliza-pero-consumo-sigue-en-aumento-noticia/',
#  'https://peru21.pe/lima/jorge-munoz-a-martin-vizcarra-por-subsidio-al-metropolitano-transferencias-por-puchos-no-sirven-nndc-noticia/',
#  'https://peru21.pe/lima/coronavirus-peru-metro-clausura-de-local-de-la-pascana-de-comas-es-ilegal-y-se-impugnara-medida-estado-de-emergencia-covid-19-nndc-noticia/',
#  'https://peru21.pe/politica/martin-vizcarra-sobre-lo-aprobado-por-el-congreso-no-tengo-ningun-temor-pero-estoy-de-salida-inmunidad-parlamentaria-nndc-noticia/',
#  'https://peru21.pe/politica/congreso-de-la-republica-martin-vizcarra-juristas-piden-al-titular-del-congreso-detener-el-proceso-de-aprobacion-de-las-reformas-noticia/',
#  'https://peru21.pe/politica/presidente-vizcarra-convoca-al-consejo-de-estado-para-abordar-impase-sobre-reforma-politica-congreso-de-la-republica-noticia/',
#  'https://peru21.pe/politica/elecciones-2021-martin-vizcarra-convoco-hoy-a-elecciones-para-abril-del-proximo-ano-noticia/',
#  'https://peru21.pe/politica/martin-vizcarra-convoco-para-manana-al-consejo-de-estado-noticia/',
#  'https://peru21.pe/politica/hospital-de-ate-se-convertira-en-el-instituto-nacional-de-medicina-critica-tras-la-pandemia-anuncio-martin-vizcarra-pandemia-noticia/']

# %%
article_link = top_articles[0]

# %%
article_link
# Out:
# 'https://peru21.pe/politica/mercedes-araoz-fiscal-de-la-nacion-archivo-denuncia-jurar-como-presidenta-noticia/'

# %%
response2 = requests.get(article_link)

# %%
from apps.article.models import Article

# %%
response2.text
# Out:
# '<!DOCTYPE html><html itemscope="" itemType="http://schema.org/WebPage" lang="es"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="viewport" content="width=device-width, initial-scale=1"/><meta name="lang" content="es"/><meta name="resource-type" content="document"/><meta content="global" name="distribution"/><meta name="robots" content="index, follow"/><meta name="GOOGLEBOT" content="index follow"/><meta name="Author" content="Peru21"/><meta name="DC.title" lang="es" content="Política: Mercedes Aráoz: Fiscal de la Nación archivó denuncia por jurar como pr | NOTICIAS PERU21 PERÚ"/><meta name="DC.description" lang="es" content="La exvicepresidenta de la República juró al cargo luego de que Martín Vizcarra disolviera el Congreso."/><meta name="DC.subject" lang="es" content="Noticias, Peru21, Peru, Mundo, Deportes, Internacional, Tecnologia, Diario, Cultura, Ciencias, Economía, Opinión"/><meta name="DC.creator" content="NOTICIAS PERU21"/><meta name="DC.publisher" content="NOTICIAS PERU21"/><meta name="DC.language" scheme="RFC1766" content="es"/><link rel="amphtml" href="https://peru21.pe/politica/mercedes-araoz-fiscal-de-la-nacion-archivo-denuncia-jurar-como-presidenta-noticia/?outputType=amp"/><title>Política: Mercedes Aráoz: Fiscal de la Nación archivó denuncia por jurar como pr | NOTICIAS PERU21 PERÚ</title><link rel="preconnect dns-prefetch" href="//cdnc.peru21.pe"/><link rel="preconnect dns-prefetch" href="//cdna.peru21.pe"/><link rel="preconnect dns-prefetch" href="//d1r08wok4169a5.cloudfront.net"/><link rel="preconnect dns-prefetch" href="//elcomercio-elcomercio-prod.cdn.arcpublishing.com"/><link rel="preconnect dns-prefetch" href="//arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com"/><link rel="preconnect dns-prefetch" href="//s.go-mpulse.net"/><link rel="preconnect dns-prefetch" href="//fonts.gstatic.com"/><link rel="preconnect dns-prefetch" href="//ajax.googleapis.com"/><link rel="preconnect dns-prefetch" href="//fonts.googleapis.com"/><link rel="preconnect dns-prefetch" href="//www.google-analytics.com"/><link rel="preconnect dns-prefetch" href="//www.googletagmanager.com"/><link rel="preconnect dns-prefetch" href="//www.facebook.com"/><link rel="preconnect dns-prefetch" href="//connect.facebook.net"/><link rel="preconnect dns-prefetch" href="//tags.bluekai.com"/><link rel="preconnect dns-prefetch" href="//tags.bkrtx.com"/><link rel="preconnect dns-prefetch" href="//static.chartbeat.com"/><link rel="preconnect dns-prefetch" href="//scomcluster.cxense.com"/><link rel="preconnect dns-prefetch" href="//sb.scorecardresearch.com"/><link rel="preconnect dns-prefetch" href="//ping.chartbeat.net"/><link rel="preconnect dns-prefetch" href="//mab.chartbeat.com"/><link rel="preconnect dns-prefetch" href="//cdn.cxense.com"/><link rel="preconnect dns-prefetch" href="//arc-subs-sdk.s3.amazonaws.com"/><link rel="preconnect dns-prefetch" href="//acdn.adnxs.com"/><link href="https://fonts.googleapis.com/css?family=Lato:300,400,700,900|Exo:500|Roboto:400,700,900&amp;display=swap" rel="stylesheet"/><link rel="stylesheet" href="https://cdnc.peru21.pe/dist/peru21/css/style.css?d=1155"/><link rel="shortcut icon" type="image/png" href="https://cdna.peru21.pe/resources/dist/peru21/images/favicon.png?d=1"/><link rel="apple-touch-icon" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon.png?d=1"/><link rel="apple-touch-icon" sizes="76x76" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-76x76.png?d=1"/><link rel="apple-touch-icon" sizes="120x120" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-120x120.png?d=1"/><link rel="apple-touch-icon" sizes="144x144" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-144x144.png?d=1"/><link rel="apple-touch-icon" sizes="152x152" href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-152x152.png?d=1"/><link rel="apple-touch-icon" sizes="180x ...

# %%
s1.article_title_class
# Out:
# 'story-header__news-title'

# %%
s1.article_body_class = 'story-content__content'

# %%
soup2 = bs4.BeautifulSoup(response2.text, 'html.parser')

# %%
soup2.prettify()
# Out:
# '<!DOCTYPE html>\n<html itemscope="" itemtype="http://schema.org/WebPage" lang="es">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n  <meta content="es" name="lang"/>\n  <meta content="document" name="resource-type"/>\n  <meta content="global" name="distribution"/>\n  <meta content="index, follow" name="robots"/>\n  <meta content="index follow" name="GOOGLEBOT"/>\n  <meta content="Peru21" name="Author"/>\n  <meta content="Política: Mercedes Aráoz: Fiscal de la Nación archivó denuncia por jurar como pr | NOTICIAS PERU21 PERÚ" lang="es" name="DC.title"/>\n  <meta content="La exvicepresidenta de la República juró al cargo luego de que Martín Vizcarra disolviera el Congreso." lang="es" name="DC.description"/>\n  <meta content="Noticias, Peru21, Peru, Mundo, Deportes, Internacional, Tecnologia, Diario, Cultura, Ciencias, Economía, Opinión" lang="es" name="DC.subject"/>\n  <meta content="NOTICIAS PERU21" name="DC.creator"/>\n  <meta content="NOTICIAS PERU21" name="DC.publisher"/>\n  <meta content="es" name="DC.language" scheme="RFC1766"/>\n  <link href="https://peru21.pe/politica/mercedes-araoz-fiscal-de-la-nacion-archivo-denuncia-jurar-como-presidenta-noticia/?outputType=amp" rel="amphtml"/>\n  <title>\n   Política: Mercedes Aráoz: Fiscal de la Nación archivó denuncia por jurar como pr | NOTICIAS PERU21 PERÚ\n  </title>\n  <link href="//cdnc.peru21.pe" rel="preconnect dns-prefetch"/>\n  <link href="//cdna.peru21.pe" rel="preconnect dns-prefetch"/>\n  <link href="//d1r08wok4169a5.cloudfront.net" rel="preconnect dns-prefetch"/>\n  <link href="//elcomercio-elcomercio-prod.cdn.arcpublishing.com" rel="preconnect dns-prefetch"/>\n  <link href="//arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com" rel="preconnect dns-prefetch"/>\n  <link href="//s.go-mpulse.net" rel="preconnect dns-prefetch"/>\n  <link href="//fonts.gstatic.com" rel="preconnect dns-prefetch"/>\n  <link href="//ajax.googleapis.com" rel="preconnect dns-prefetch"/>\n  <link href="//fonts.googleapis.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.google-analytics.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.googletagmanager.com" rel="preconnect dns-prefetch"/>\n  <link href="//www.facebook.com" rel="preconnect dns-prefetch"/>\n  <link href="//connect.facebook.net" rel="preconnect dns-prefetch"/>\n  <link href="//tags.bluekai.com" rel="preconnect dns-prefetch"/>\n  <link href="//tags.bkrtx.com" rel="preconnect dns-prefetch"/>\n  <link href="//static.chartbeat.com" rel="preconnect dns-prefetch"/>\n  <link href="//scomcluster.cxense.com" rel="preconnect dns-prefetch"/>\n  <link href="//sb.scorecardresearch.com" rel="preconnect dns-prefetch"/>\n  <link href="//ping.chartbeat.net" rel="preconnect dns-prefetch"/>\n  <link href="//mab.chartbeat.com" rel="preconnect dns-prefetch"/>\n  <link href="//cdn.cxense.com" rel="preconnect dns-prefetch"/>\n  <link href="//arc-subs-sdk.s3.amazonaws.com" rel="preconnect dns-prefetch"/>\n  <link href="//acdn.adnxs.com" rel="preconnect dns-prefetch"/>\n  <link href="https://fonts.googleapis.com/css?family=Lato:300,400,700,900|Exo:500|Roboto:400,700,900&amp;display=swap" rel="stylesheet"/>\n  <link href="https://cdnc.peru21.pe/dist/peru21/css/style.css?d=1155" rel="stylesheet"/>\n  <link href="https://cdna.peru21.pe/resources/dist/peru21/images/favicon.png?d=1" rel="shortcut icon" type="image/png"/>\n  <link href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon.png?d=1" rel="apple-touch-icon"/>\n  <link href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-76x76.png?d=1" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-120x120.png?d=1" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="https://cdna.peru21.pe/resources/dist/peru21/images/apple-touch-icon-144x144.png?d=1" rel="apple-touch ...

# %%
soup2.select('.'+s1.article_title_class)[0].text
# Out:
# ' Mercedes Aráoz: Fiscal de la Nación archivó denuncia por jurar como presidenta'

# %%
soup2.select('.'+s1.article_body_class)[0].text
# Out:
# 'La fiscal de la Nación, Zoraida Ávalos, archivó la denuncia interpuesta contra la exvicepresidenta de la República, Mercedes Araoz, por jurar al cargo de mandataria encargada luego de que el presidente Martín Vizcarra disolviera el Congreso.Ávalos concluyó que “no hay mérito” para continuar con la investigación por presunta usurpación de funciones, que también incluía al extitular del Parlamento, Pedro Olaechea, al advertir que fue producto de “tensiones políticas”.“La segunda vicepresidenta juramentada no ejerció ninguna función y renunció al cargo antes de realizar acto oficial alguno. Desde este punto de vista, las conductas atribuidas no tuvieron una afectación concreta al bien jurídico”, señala la resolución a la que accedió Perú21.MIRA: Martín Vizcarra convocó hoy a Elecciones Generales para el 11 de abril del 2021El 30 de setiembre de 2019, momentos después de la decisión de Vizcarra, el Legislativo contraatacó y acordó suspenderlo de sus funciones por incapacidad temporal para gobernar. Acto seguido, convocó a la vicepresidenta Araoz para que jurara al puesto en su lugar.Sin embargo, la juramentación no tuvo reconocimiento de las Fuerzas Armadas, que respaldaron en todo momento al hoy jefe de Estado. Y Aráoz renunció al puesto al día siguiente.VIDEO RECOMENDADOAgenda Fútbol: conoce la agenda de los partidos para hoy jueves 9 de julio del 2020 | VIDEO '
